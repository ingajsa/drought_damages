# %% [markdown]
# # EM-Dat and Natcat Fusion

# %%
# prepare NatCat Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline

# %%
path_cluster = "/home/insauer/mnt/primap/USERS/annikag/drought/isimip/data"

# %% [markdown]
# ## 1. Conversion of NatCat and EM-Dat to CPI 2015 and PPP 2015

# %% [markdown]
# Natcat Data is given in current USD and current exchange rates 'tot_dam_currentUSD_currentXR',
# and in constant 2016 USD at current exchange rates 'tot_dam_currentUSD_currentXR',
#
# We want to convert to constant 2015 USD MER and to constant 2015 USD MER to use then the GDPuc tool to convert to
# constant 2015 USD PPP and constant 2015 USD PPP
#
# 1. conversion to constant 2015 exchange rate ('tot_dam_currentUSD_constant2015XR')
# 2. conversion to constant 2015 USD ('tot_dam_constant2015USD_constant2015XR')
# 3. conversion to PPP

# %%
damage_natcat = pd.read_csv(f"{path_cluster}/damages/natcat_dry_CPI_adjusted_annika_more_info.csv", index_col=0)
damage_natcat = damage_natcat.loc[damage_natcat.subtype == "dr:Drought"]
damage_natcat = damage_natcat.loc[~damage_natcat.iso3.isna()]

# %%
# rename columns to comprehensive units
damage_natcat=damage_natcat.rename(columns={'tot_loss': 'tot_damage_currentUSD_MER',
                              'tot_loss_CPI': 'tot_damage_constant2016USD'})

# %%
# delete multi country events
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
damage_natcat.columns
# Out:
# Index(['year', 'begin', 'begin_yr', 'begin_mon', 'end', 'end_yr', 'end_mon',
#        'event', 'type', 'subtype', 'iso3', 'country', 'country_read',
#        'Continent', 'tot_damage_currentUSD_MER', 'ins_loss', 'tot_loss_GDP',
#        'tot_loss_GCP', 'tot_damage_constant2016USD', 'Fatalities', 'Longitude',
#        'Latitude', 'Reg_name', 'ID', 'Reg_ID', 'CPI_conv', 'GDP_conv',
#        'unexact_conv', 'comment', 'MR Number', 'MR ID',
#        'Association Type \n(Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me') ',
#        'Country Name', 'Affected Area', 'Affected Area (Detail)',
#        'Description', 'Catastrophe Class', 'Geocoded Place'],
#       dtype='object')

# %%
# rename SSD to SDN as before 2011 it did not exist
damage_natcat.loc[damage_natcat['iso3']=='SSD', 'iso3']='SDN'
# Out:
# Empty DataFrame
# Columns: [year, begin, begin_yr, begin_mon, end, end_yr, end_mon, event, type, subtype, iso3, country, country_read, Continent, tot_damage_currentUSD_MER, ins_loss, tot_loss_GDP, tot_loss_GCP, tot_damage_constant2016USD, Fatalities, Longitude, Latitude, Reg_name, ID, Reg_ID, CPI_conv, GDP_conv, unexact_conv, comment, MR Number, MR ID, Association Type
# (Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me') , Country Name, Affected Area, Affected Area (Detail), Description, Catastrophe Class, Geocoded Place]
# Index: []
#
# [0 rows x 38 columns]

# %% [markdown]
# ### 1.1 conversion to constant 2015 exchange rate ('tot_dam_currentUSD_constant2015XR')

# %% [markdown]
# Exchange rates:
#
# We use the wdi dataset "Official exchange rate (LCU per US$, period average)"
#
# https://data.worldbank.org/indicator/PA.NUS.FCRF?skipRedirection=true&view=map
#
# For Taiwan TWN we use data from PWT v.10.1

# %%
natcat_current_USD_MER=damage_natcat[['iso3','year','tot_damage_currentUSD_MER']]
natcat_current_USD_MER=natcat_current_USD_MER.rename(columns={'iso3': 'iso3c',
                                                              'tot_damage_currentUSD_MER': 'value'})

# %%
natcat_current_USD_MER['value']=natcat_current_USD_MER['value']*1000000

# %%
natcat_current_USD_MER=natcat_current_USD_MER.reset_index()

# %%
natcat_current_USD_MER
# Out:
#         id iso3c  year         value
# 0        0   ESP  1980  1.500000e+09
# 1        9   SOM  1980  6.000000e+06
# 2       10   MOZ  1980  2.160000e+07
# 3       11   GMB  1980  1.050000e+07
# 4       12   MLI  1980  2.500000e+07
# ..     ...   ...   ...           ...
# 914  29778   FRA  2016  1.000000e+05
# 915  29936   CHN  2016  4.500000e+08
# 916  30097   CHN  2016  6.000000e+07
# 917  30236   LKA  2016  0.000000e+00
# 918  30375   TZA  2016  1.500000e+06
#
# [919 rows x 4 columns]

# %%
natcat_current_USD_MER.to_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_current_USD_MER_input_GDPuc.csv')

# %%
natcat_constant2015USD_PPP=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant_Int_2015PPP_output_GDPuc.csv')
natcat_constant2017USD_PPP=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant_Int_2017PPP_output_GDPuc.csv')

# %%
natcat_constant2017USD_PPP
# Out:
#        X     id iso3c  year         value
# 0      0      0   ESP  1980  5.166359e+09
# 1      1      9   SOM  1980  1.179279e+05
# 2      2     10   MOZ  1980           NaN
# 3      3     11   GMB  1980  6.608654e+07
# 4      4     12   MLI  1980  1.322487e+08
# ..   ...    ...   ...   ...           ...
# 914  914  29778   FRA  2016  1.180028e+05
# 915  915  29936   CHN  2016  7.449149e+08
# 916  916  30097   CHN  2016  9.932199e+07
# 917  917  30236   LKA  2016  0.000000e+00
# 918  918  30375   TZA  2016  3.789389e+06
#
# [919 rows x 5 columns]

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
damage_natcat['tot_damage_constant2015USD_PPP']=np.array(natcat_constant2015USD_PPP['value']/1000000)
damage_natcat['tot_damage_constant2017USD_PPP']=np.array(natcat_constant2017USD_PPP['value']/1000000)
damage_natcat['conversion_source']='GDPuc_currentUSD_to_constantXPPP'

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
damage_natcat.loc[damage_natcat['tot_damage_constant2017USD_PPP'].isna(), 'conversion_source']='GDPuc_constant2016MER_to_constantXPPP'

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
natcat_constant_2016USD_MER=damage_natcat.loc[damage_natcat['tot_damage_constant2015USD_PPP'].isna(), ['iso3','year', 'tot_damage_constant2016USD','Reg_name']]
natcat_constant_2016USD_MER=natcat_constant_2016USD_MER.rename(columns={'iso3': 'iso3c',
                                                              'tot_damage_constant2016USD': 'value',
                                                              'Reg_name': 'region'})
natcat_constant_2016USD_MER
# Out:
#       iso3c  year       value region
# id
# 10      MOZ  1980   62.914456    SSA
# 168     DJI  1980   21.167744    ARA
# 420     CUB  1981  156.836257    CAR
# 455     GIN  1981  174.262508    SSA
# 457     MOZ  1981  174.262508    SSA
# ...     ...   ...         ...    ...
# 27487   PRK  2015  101.261513    CHN
# 27499   VGB  2015    0.151892    CAR
# 27634   CUB  2015   52.255920    CAR
# 27842   TWN  2015    0.098988    CHN
# 29017   CUB  2016    0.000000    CAR
#
# [77 rows x 4 columns]

# %%
natcat_constant_2016USD_MER.to_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant_2016USD_MER_input_GDPuc.csv')

# %%
natcat_constant_2015USD_PPP=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant_Int_2015PPP_output_GDPuc.csv')
natcat_constant_2017USD_PPP=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant_Int_2017PPP_output_GDPuc.csv')

# %%
natcat_constant_2015USD_PPP
# Out:
#        id iso3c  year       value region
# 0      10   MOZ  1980  191.077327    SSA
# 1     168   DJI  1980   36.254641    ARA
# 2     420   CUB  1981         NaN    CAR
# 3     455   GIN  1981  467.278117    SSA
# 4     457   MOZ  1981  529.252198    SSA
# ..    ...   ...   ...         ...    ...
# 72  27487   PRK  2015         NaN    CHN
# 73  27499   VGB  2015         NaN    CAR
# 74  27634   CUB  2015         NaN    CAR
# 75  27842   TWN  2015         NaN    CHN
# 76  29017   CUB  2016         NaN    CAR
#
# [77 rows x 5 columns]

# %%
damage_natcat.loc[damage_natcat['tot_damage_constant2015USD_PPP'].isna(),'tot_damage_constant2015USD_PPP']=np.array(natcat_constant_2015USD_PPP['value'])

# %%
damage_natcat.loc[damage_natcat['tot_damage_constant2017USD_PPP'].isna(),'tot_damage_constant2017USD_PPP']=np.array(natcat_constant_2017USD_PPP['value'])

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
missing_countries=list(set(damage_natcat.loc[damage_natcat['tot_damage_constant2015USD_PPP'].isna(), 'iso3']))
missing_countries
# Out:
# ['TWN', 'CUB', 'TKL', 'PRK', 'VGB', 'SYR', 'ASM']

# %%
# use pwt price levels for conversion in CUB, TWN, SYR, 'VGB'
for c in [ 'TWN', 'SYR', 'VGB']:
    pl_c_2016 = pwt.loc[(pwt['countrycode']==c) & (pwt['year']==2016), 'pl_n'].values[0]

    pl_USA_2015 = pwt.loc[(pwt['countrycode']=='USA') & (pwt['year']==2015), 'pl_n'].values[0]
    pl_USA_2017 = pwt.loc[(pwt['countrycode']=='USA') & (pwt['year']==2017), 'pl_n'].values[0]

    
    conv_fac_2015 = pl_USA_2015/pl_c_2016
    conv_fac_2017 = pl_USA_2017/pl_c_2016
    
    damage=damage_natcat.loc[(damage_natcat['iso3']==c), 'tot_damage_constant2016USD'].values
    
    damage_natcat.loc[(damage_natcat['iso3']==c), 'tot_damage_constant2015USD_PPP'] = damage*conv_fac_2015
    damage_natcat.loc[(damage_natcat['iso3']==c), 'tot_damage_constant2017USD_PPP'] = damage*conv_fac_2017

# %%
damage_natcat.loc[(damage_natcat['iso3'].isin([ 'TWN', 'SYR', 'VGB'])), 'conversion_source']='pwt_pl_n_constant2016USD_to_constantXUSD_PPP'

# %%
# convert the missings to USA and NZL...

# %%
(damage_natcat.loc[(damage_natcat['iso3']=='NZL'),'tot_damage_constant2015USD_PPP']/damage_natcat.loc[(damage_natcat['iso3']=='NZL'),'tot_damage_constant2016USD']).values
# Out:
# array([0.93740846, 0.9319857 , 0.93308824, 1.00479599, 1.0011087 ,
#        0.97341875, 0.97098735, 0.98950198, 0.98528244, 0.97037856,
#        0.96592278, 0.96269796])

# %%
damage_natcat.loc[(damage_natcat['iso3'].isin([ 'ASM', 'TKL']))]
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 10522  1998  01/06/1998 00:00      1998          6  30/06/1998 00:00    1998
# 23150  2011  01/09/2011 00:00      2011          9  31/10/2011 00:00    2011
#
#        end_mon    event type     subtype  ...  \
# id                                        ...
# 10522        6  Drought    D  dr:Drought  ...
# 23150       10  Drought    D  dr:Drought  ...
#
#       Association Type \n(Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me')   \
# id
# 10522                                             Single
# 23150                                            Country
#
#          Country Name    Affected Area Affected Area (Detail)  \
# id
# 10522  American Samoa               E,   Aunu'u, Ta'u Islands
# 23150         Tokelau  Entire country,                    n.a
#
# ...

# %%
conf_NZL_2015 = (damage_natcat.loc[(damage_natcat['iso3']=='NZL') & (damage_natcat['year']==2010),'tot_damage_constant2015USD_PPP']/damage_natcat.loc[(damage_natcat['iso3']=='NZL') & (damage_natcat['year']==2010),'tot_damage_constant2016USD']).values[0]
conf_NZL_2017 = (damage_natcat.loc[(damage_natcat['iso3']=='NZL') & (damage_natcat['year']==2010),'tot_damage_constant2015USD_PPP']/damage_natcat.loc[(damage_natcat['iso3']=='NZL') & (damage_natcat['year']==2010),'tot_damage_constant2016USD']).values[0]

# %%
conf_USA_2015 = (damage_natcat.loc[(damage_natcat['iso3']=='USA') & (damage_natcat['year']==1998),'tot_damage_constant2015USD_PPP']/damage_natcat.loc[(damage_natcat['iso3']=='USA') & (damage_natcat['year']==1998),'tot_damage_constant2016USD']).values[0]
conf_USA_2017 = (damage_natcat.loc[(damage_natcat['iso3']=='USA') & (damage_natcat['year']==1998),'tot_damage_constant2015USD_PPP']/damage_natcat.loc[(damage_natcat['iso3']=='USA') & (damage_natcat['year']==1998),'tot_damage_constant2016USD']).values[0]

# %%
damage_natcat.loc[(damage_natcat['iso3']=='TKL'),'tot_damage_constant2015USD_PPP']=damage_natcat.loc[(damage_natcat['iso3']=='TKL'),'tot_damage_constant2016USD']*conf_NZL_2015
damage_natcat.loc[(damage_natcat['iso3']=='TKL'),'tot_damage_constant2017USD_PPP']=damage_natcat.loc[(damage_natcat['iso3']=='TKL'),'tot_damage_constant2016USD']*conf_NZL_2017

# %%
damage_natcat.loc[(damage_natcat['iso3']=='ASM'),'tot_damage_constant2015USD_PPP']=damage_natcat.loc[(damage_natcat['iso3']=='ASM'),'tot_damage_constant2016USD']*conf_USA_2015
damage_natcat.loc[(damage_natcat['iso3']=='ASM'),'tot_damage_constant2017USD_PPP']=damage_natcat.loc[(damage_natcat['iso3']=='ASM'),'tot_damage_constant2016USD']*conf_USA_2017

# %%
damage_natcat.loc[damage_natcat['tot_damage_constant2015USD_PPP'].isna()]
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 420    1981  01/01/1981 00:00      1981          1  31/01/1983 00:00    1983
# 8126   1995  01/05/1995 00:00      1995          5  31/05/1995 00:00    1995
# 10436  1998  01/05/1998 00:00      1998          5  31/08/1998 00:00    1998
# 11314  1999  01/05/1999 00:00      1999          5  31/05/1999 00:00    1999
# 11962  2000  01/01/2000 00:00      2000          1  31/08/2000 00:00    2000
# 12391  2000  01/07/2000 00:00      2000          7  31/07/2000 00:00    2000
# 13053  2001  01/03/2001 00:00      2001          3  30/07/2001 00:00    2001
# 13085  2001  01/04/2001 00:00      2001          4  30/04/2001 00:00    2001
# 15482  2004  01/05/2004 00:00      2004          5  28/02/2005 00:00    2005
# 20079  2008  01/12/2008 00:00      2008         12  01/06/2011 00:00    2011
# 23537  2012  01/01/2012 00:00      2012          1  22/04/2012 00:00    2012
# ...

# %%
#CUBA https://fred.stlouisfed.org/searchresults/?st=ppp%20tkl
xr_cuba=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/cuba/xr_cuba.csv')
def_cuba=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/cuba/deflator_cuba.csv')
current_ppp=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/cuba/xr_ppp_cuba.csv')

# %%
current_ppp
# Out:
#           DATE  PPPTTLCUA618NUPN
# 0   1970-01-01          0.596360
# 1   1971-01-01          0.633739
# 2   1972-01-01          0.650671
# 3   1973-01-01          0.637873
# 4   1974-01-01          0.645479
# 5   1975-01-01          0.618160
# 6   1976-01-01          0.589826
# 7   1977-01-01          0.527129
# 8   1978-01-01          0.539037
# 9   1979-01-01          0.510003
# 10  1980-01-01          0.484531
# 11  1981-01-01          0.433644
# 12  1982-01-01          0.400656
# 13  1983-01-01          0.392016
# 14  1984-01-01          0.388841
# 15  1985-01-01          0.368537
# 16  1986-01-01          0.355352
# 17  1987-01-01          0.336194
# 18  1988-01-01          0.329889
# 19  1989-01-01          0.323610
# 20  1990-01-01          0.323847
# 21  1991-01-01          0.288386
# 22  1992-01-01          0.297622
# 23  1993-01-01          0.328561
# 24  1994-01-01          0.388480
# 25  1995-01-01          0.434445
# 26  1996-01-01          0.427137
# ...

# %%
xr_cuba['year']=xr_cuba['DATE'].str[:4].astype(int)
def_cuba['year']=def_cuba['DATE']str[:4].astype(int)

# %%
def_cuba
# Out:
#           DATE  A191RD3A086NBEA
# 0   1929-01-01            8.778
# 1   1930-01-01            8.457
# 2   1931-01-01            7.587
# 3   1932-01-01            6.700
# 4   1933-01-01            6.514
# ..         ...              ...
# 90  2019-01-01          104.008
# 91  2020-01-01          105.381
# 92  2021-01-01          110.213
# 93  2022-01-01          117.973
# 94  2023-01-01          122.273
#
# [95 rows x 2 columns]

# %%
#
for y in years:
    # convert to LCU
    xr=xr_cuba.loc[xr_cuba['year']==y,'FXRATECUA618NUPN'].values[0]
    dam_lcu=xr*damage_natcat.loc[(damage_natcat['iso3']=='CUB')&(damage_natcat['year']==y),'tot_damage_currentUSD_MER']

    # deflate
    def_=def_cuba.loc[def_cuba['year']==2015,'A191RD3A086NBEA'].values[0]/def_cuba.loc[def_cuba['year']==y,'A191RD3A086NBEA'].values[0]
    dam_const_2015_LCU=def_*dam_lcu
    # convert to PPP
    xr_ppp=current_ppp.loc[current_ppp['year']==y,'PPPTTLCUA618NUPN'].values[0]
    current_ppp= dam_const_2015/xr_ppp
    # convert to constant PPP
    pl_USA_y2015 = pwt.loc[(pwt['countrycode']=='USA') & (pwt['year']==2015), 'pl_n'].values[0]/pwt.loc[(pwt['countrycode']=='USA') & (pwt['year']==y), 'pl_n'].values[0]
    current_ppp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/climada_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[556], line 4
#       1 #
#       2 for y in years:
# ...

# %%
natcat_LCU=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_currentLCU_output_GDPuc.csv')

# %%
natcat_LCU
# Out:
#        X     id iso3c  year         value
# 0      0      0   ESP  1980  6.463500e+08
# 1      1      9   SOM  1980  1.726860e+08
# 2      2     10   MOZ  1980  6.998400e+05
# 3      3     11   GMB  1980  1.807050e+07
# 4      4     12   MLI  1980  5.281990e+09
# ..   ...    ...   ...   ...           ...
# 914  914  29778   FRA  2016  9.040351e+04
# 915  915  29936   CHN  2016  2.990025e+09
# 916  916  30097   CHN  2016  3.986700e+08
# 917  917  30236   LKA  2016  0.000000e+00
# 918  918  30375   TZA  2016  3.265629e+09
#
# [919 rows x 5 columns]

# %%
damage_natcat['tot_damage_currentLCU']=np.array(natcat_LCU['value'])/1000000

# %%
#'LTU' - pwt
# 'TWN'- pwt
# 'TKL'- nzl
# 'VGB'- usa
# 'SRB'- ?
# 'SOM'- ?
# 'PRK'- ?
# 'MNE'- ?
# 'SSD'- rename to sudan prior to 2011
# 'HRV'-?
# 'ASM'- usa
# 'ROU' pwt
missings=list(set(damage_natcat.loc[damage_natcat['tot_damage_currentLCU'].isna(),'iso3']))

# %%
missings
# Out:
# ['LTU', 'TWN', 'TKL', 'VGB', 'SRB', 'SOM', 'PRK', 'MNE', 'HRV', 'ASM', 'ROU']

# %%
pwt=pd.read_excel('/home/insauer/projects/droughts_annika/inga_data/socio_economic/pwt1001.xlsx', sheet_name='Data')
pwt
# Out:
#       countrycode   country   currency_unit  year         rgdpe         rgdpo  \
# 0             ABW     Aruba  Aruban Guilder  1950           NaN           NaN
# 1             ABW     Aruba  Aruban Guilder  1951           NaN           NaN
# 2             ABW     Aruba  Aruban Guilder  1952           NaN           NaN
# 3             ABW     Aruba  Aruban Guilder  1953           NaN           NaN
# 4             ABW     Aruba  Aruban Guilder  1954           NaN           NaN
# ...           ...       ...             ...   ...           ...           ...
# 12805         ZWE  Zimbabwe       US Dollar  2015  40141.617188  39798.644531
# 12806         ZWE  Zimbabwe       US Dollar  2016  41875.203125  40963.191406
# 12807         ZWE  Zimbabwe       US Dollar  2017  44672.175781  44316.742188
# 12808         ZWE  Zimbabwe       US Dollar  2018  44325.109375  43420.898438
# 12809         ZWE  Zimbabwe       US Dollar  2019  42296.062500  40826.570312
#
# ...

# %%
xr= pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/API_PA.NUS.FCRF_DS2_en_csv_v2_446341_xr/API_PA_NUS_FCRF_DS2_en_csv_v2_446341_xr.csv', header=2)
xr
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name Indicator Code  \
# 0    Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 1    Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 2    Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# 3    Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF
# ...

# %%
# list for countries without own currency
cwooc={'TKL': 'NZL',
       'PRI': 'USA',
       'TUV': 'AUS',
       'MHL': 'USA',
       'ASM': 'USA'
      }

# %%
for c in missings:
    print(c)
    # use NZL for TKL as they have the same currency
    years=list(set(damage_natcat.loc[damage_natcat['iso3']==c,'year'].values))
    for y in years:
        if not np.isin(c, ['VGB', 'ASM']):
            xr_c_y=1.
        else:
            try:
                if np.isin(c,['TKL']):
                    xr_c_y=pwt.loc[(pwt['countrycode']=='NZL') & (pwt['year']==y), 'xr'].values[0]
                    print(xr_c_y)
                else:
                    xr_c_y=pwt.loc[(pwt['countrycode']==c) & (pwt['year']==y), 'xr'].values[0]
                source='pwt'
            except IndexError:
                if np.isin(c,['TKL']):
                    xr_c_y=xr.loc[xr['Country Code']=='NZL', str(y)].values[0]
                    print(xr_c_y)
                else:
                    xr_c_y=xr.loc[xr['Country Code']==c, str(y)].values[0]
                source='wdi'
        damage_usd_to_lcu=damage_natcat.loc[(damage_natcat['iso3']==c) & (damage_natcat['year']==y), 'tot_damage_currentUSD_MER']*xr_c_y
        damage_natcat.loc[(damage_natcat['iso3']==c) & (damage_natcat['year']==y), 'tot_damage_currentLCU']=damage_usd_to_lcu
# Out:
# LTU
# TWN
# TKL
# 1.26581069673447
# VGB
# SRB
# SOM
# PRK
# MNE
# HRV
# ASM
# ROU

# %%
# we have to except these 11 missing events
damage_natcat.loc[damage_natcat['tot_damage_currentLCU'].isna()]
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 3674   1988  01/06/1988 00:00      1988          6  31/08/1988 00:00    1988
# 9418   1997  01/02/1997 00:00      1997          2  28/02/1997 00:00    1997
# 11314  1999  01/05/1999 00:00      1999          5  31/05/1999 00:00    1999
# 11960  2000  01/01/2000 00:00      2000          1  31/07/2001 00:00    2001
# 11962  2000  01/01/2000 00:00      2000          1  31/08/2000 00:00    2000
# 13053  2001  01/03/2001 00:00      2001          3  30/07/2001 00:00    2001
# 16238  2005  01/04/2005 00:00      2005          4  31/12/2007 00:00    2007
# 19246  2008  01/01/2008 00:00      2008          1  31/12/2008 00:00    2008
# 23978  2012  01/05/2012 00:00      2012          5  30/06/2012 00:00    2012
# 26023  2014  01/01/2014 00:00      2014          1  31/07/2014 00:00    2014
# 27487  2015  01/01/2015 00:00      2015          1  07/10/2015 13:43    2015
#
# ...

# %%
xr.loc[xr['Country Code']=='HRV'].iloc[:,4:-1].values[0]
# Out:
# array([       nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan, 0.26329825, 3.57914892, 5.99801142,
#        5.23075608, 5.43416117, 6.16058258, 6.36328567, 7.11174283,
#        8.27766642, 8.341541  , 7.8716825 , 6.70496883, 6.03434067,
#        5.94923692, 5.83779325, 5.36453567, 4.93503975, 5.28394642,
#        5.49801058, 5.34386975, 5.85029183, 5.70488017, 5.74816542,
#        6.85830375, 6.80599017, 6.623831  , 6.27902525, 6.62254517,
#        6.6140555 , 6.36008317, 7.1597415 ,        nan])

# %%
plt.plot(xr.columns[4:-1].astype(int),xr.loc[xr['Country Code']=='HRV'].iloc[:,4:-1].values[0])

# %%
xr.loc[xr['Country Code']=='PRK']
# Out:
#                   Country Name Country Code  \
# 193  Korea, Dem. People's Rep.          PRK
#
#                                         Indicator Name Indicator Code  1960  \
# 193  Official exchange rate (LCU per US$, period av...    PA.NUS.FCRF   NaN
#
#      1961  1962  1963  1964  1965  ...  2015  2016  2017  2018  2019  2020  \
# 193   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
#      2021  2022  2023  Unnamed: 68
# 193   NaN   NaN   NaN          NaN
#
# [1 rows x 69 columns]

# %%
yy=np.where(~xr.loc[xr['Country Code']=='SOM'].iloc[:,4:-1].isna())[1]

# %%
np.array( xr.columns[4:-1].astype(int))
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#        2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023])

# %%
x = np.array( xr.columns[4:-1].astype(int))[yy]
y = np.array(xr.loc[xr['Country Code']=='SOM'].iloc[:,4:-1])[0][yy]
cs = CubicSpline(x, y)
plt.plot(np.array( xr.columns[4:-1].astype(int)),cs(np.array( xr.columns[4:-1].astype(int)),0))
plt.plot(xr.columns[4:-1].astype(int),xr.loc[xr['Country Code']=='SOM'].iloc[:,4:-1].values[0], label='SOM')

# %%
cs(np.array( xr.columns[4:-1].astype(int)),1)
# Out:
# array([-4.50468440e-07,  2.25234220e-07, -4.50468440e-07,  1.57663954e-06,
#        -5.85608972e-06,  2.18477193e-05, -8.15347876e-05,  3.04291431e-04,
#        -1.13563094e-03,  4.23823232e-03, -1.58172983e-02,  1.61259592e-02,
#        -5.36891560e-01, -4.09734739e-01,  1.20455515e-01, -3.15873224e-02,
#         5.89377437e-03,  8.01222494e-03, -3.79426741e-02,  1.43758472e-01,
#        -5.37091212e-01,  2.00460638e+00,  5.88471570e+00,  2.93450581e+00,
#         1.01818610e+01,  2.74365000e+01,  3.60164889e+01,  2.55673692e+01,
#         1.57072284e+02,  5.02637744e+02,  8.83627514e+02,  1.21987473e+03,
#         1.51137940e+03,  1.75814152e+03,  1.96016109e+03,  2.11743811e+03,
#         2.22997258e+03,  2.29776450e+03,  2.32081387e+03,  2.29912069e+03,
#         2.23268495e+03,  2.12150667e+03,  1.96558584e+03,  1.76492246e+03,
#         1.51951652e+03,  1.22936804e+03,  8.94477008e+02,  5.14843425e+02,
# ...

# %%
# convert to constant LCU
natcat_currentLCU=damage_natcat[['iso3','year','tot_damage_currentLCU', 'Reg_name']]
natcat_currentLCU=natcat_currentLCU.rename(columns={'iso3': 'iso3c',
                                                              'tot_damage_currentLCU': 'value',
                                                                'Reg_name': 'region'})

# %%
natcat_currentLCU
# Out:
#       iso3c  year        value region
# id
# 0       ESP  1980   646.350000    EUR
# 9       SOM  1980    37.770000    SSA
# 10      MOZ  1980     0.699840    SSA
# 11      GMB  1980    18.070500    SSA
# 12      MLI  1980  5281.990000    SSA
# ...     ...   ...          ...    ...
# 29778   FRA  2016     0.090404    EUR
# 29936   CHN  2016  2990.025000    CHN
# 30097   CHN  2016   398.670000    CHN
# 30236   LKA  2016     0.000000    SWA
# 30375   TZA  2016  3265.629000    SSA
#
# [919 rows x 4 columns]

# %%
natcat_currentLCU['value']=natcat_currentLCU['value']*1000000

# %%
natcat_currentLCU['value']
# Out:
# id
# 0        6.463500e+08
# 9        3.777000e+07
# 10       6.998400e+05
# 11       1.807050e+07
# 12       5.281990e+09
#              ...
# 29778    9.040351e+04
# 29936    2.990025e+09
# 30097    3.986700e+08
# 30236    0.000000e+00
# 30375    3.265629e+09
# Name: value, Length: 919, dtype: float64

# %%
natcat_currentLCU.to_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_currentLCU_input_GDPuc.csv')

# %%
gdpuc_constant_LCU_2015=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant2015LCU_output_GDPuc.csv')
gdpuc_constant_LCU_2017=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/natcat_constant2015LCU_output_GDPuc.csv')

# %%
gdpuc_constant_LCU_2015
# Out:
#        X     id iso3c  year         value
# 0      0      0   ESP  1980  7.442502e+09
# 1      1      9   SOM  1980  3.043266e+07
# 2      2     10   MOZ  1980           NaN
# 3      3     11   GMB  1980  5.238657e+08
# 4      4     12   MLI  1980  1.299660e+08
# ..   ...    ...   ...   ...           ...
# 914  914  29778   FRA  2016  9.948016e+04
# 915  915  29936   CHN  2016  4.437548e+08
# 916  916  30097   CHN  2016  5.916731e+07
# 917  917  30236   LKA  2016  0.000000e+00
# 918  918  30375   TZA  2016  1.395712e+06
#
# [919 rows x 5 columns]

# %%
gdpuc_constant_LCU_2015
# Out:
#        X     id iso3c  year         value
# 0      0      0   ESP  1980  7.442502e+09
# 1      1      9   SOM  1980  3.043266e+07
# 2      2     10   MOZ  1980           NaN
# 3      3     11   GMB  1980  5.238657e+08
# 4      4     12   MLI  1980  1.299660e+08
# ..   ...    ...   ...   ...           ...
# 914  914  29778   FRA  2016  9.948016e+04
# 915  915  29936   CHN  2016  4.437548e+08
# 916  916  30097   CHN  2016  5.916731e+07
# 917  917  30236   LKA  2016  0.000000e+00
# 918  918  30375   TZA  2016  1.395712e+06
#
# [919 rows x 5 columns]

# %%
damage_natcat['tot_damage_constantLCU2015']=np.array(gdpuc_constant_LCU_2015['value'])/1000000
damage_natcat['tot_damage_constantLCU2017']=np.array(gdpuc_constant_LCU_2017['value'])/1000000

# %%
# use regional cpis

# %%
# GIN


EMDAT_CPI =['GIN','MDA', 'MOZ','STP','AFG','']
country_list_USA=['VGB','ASM']
country_list_NZL=['TKL']
# canada use cpi
canada

# %%
missings=list(set(damage_natcat.loc[damage_natcat['tot_damage_constantLCU2015'].isna(),'iso3']))
missings
# Out:
# ['GIN',
#  'MDA',
#  'MOZ',
#  'STP',
#  'AFG',
#  'VGB',
#  'HRV',
#  'TZA',
#  'CAN',
#  'DJI',
#  'POL',
#  'TKL',
#  'KHM',
#  'PRK',
#  'SYR',
#  'LTU',
#  'VEN',
#  'TWN',
#  'ERI',
#  'HUN',
#  'SRB',
#  'SOM',
#  'MNE',
#  'LBR',
#  'ASM',
#  'ROU']

# %%
damage_natcat.loc[damage_natcat['iso3']=='ASM']
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 10522  1998  01/06/1998 00:00      1998          6  30/06/1998 00:00    1998
#
#        end_mon    event type     subtype  ...  \
# id                                        ...
# 10522        6  Drought    D  dr:Drought  ...
#
#       Association Type \n(Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me')   \
# id
# 10522                                             Single
#
#          Country Name Affected Area Affected Area (Detail)  \
# id
# 10522  American Samoa            E,   Aunu'u, Ta'u Islands
#
#                                 Description  Catastrophe Class  \
# id
# 10522  Lack of rain. Water supply affected.                  0
#
#        Geocoded Place  tot_damage_currentLCU  tot_damage_constantLCU2015  \
# id
# 10522      ASM: Aunuu                    0.5                         NaN
#
# ...

# %%
damage_natcat['cf_PPP2015']=damage_natcat['tot_damage_constantLCU2015']/damage_natcat['tot_damage_currentUSD_MER']
damage_natcat['cf_PPP2017']=damage_natcat['tot_damage_constantLCU2015']/damage_natcat['tot_damage_currentUSD_MER']

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
#gin -regional mean 
#mda - ?
#moz
#cub
#stp
#afg
#VGB -USD
#SSD - use SDN before 2011
#HRV - ?
#CAN - ?
#DJI
#POL
#TKL - USD
#KHM -?
#
list(set(damage_natcat.loc[damage_natcat['tot_damage_constantLCU2015'].isna(),'iso3']))
# Out:
# ['GIN',
#  'MDA',
#  'MOZ',
#  'STP',
#  'AFG',
#  'VGB',
#  'HRV',
#  'TZA',
#  'CAN',
#  'DJI',
#  'POL',
#  'TKL',
#  'KHM',
#  'PRK',
#  'SYR',
#  'LTU',
#  'VEN',
#  'TWN',
#  'ERI',
#  'HUN',
#  'SRB',
#  'SOM',
#  'MNE',
#  'LBR',
#  'ASM',
#  'ROU']

# %%
damage_natcat.loc[damage_natcat['iso3']=='AFG']
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 12195  2000  01/05/2000 00:00      2000          5  31/12/2002 00:00    2002
# 17395  2006  01/07/2006 00:00      2006          7  30/11/2006 00:00    2006
# 22431  2011  01/01/2011 00:00      2011          1  15/01/2012 00:00    2012
#
#        end_mon    event type     subtype  ... Country Name    Affected Area  \
# id                                        ...
# 12195       12  Drought    D  dr:Drought  ...  Afghanistan               S,
# 17395       11  Drought    D  dr:Drought  ...  Afghanistan  Entire country,
# 22431        1  Drought    D  dr:Drought  ...  Afghanistan    N, NE, W, C,
#
#                                   Affected Area (Detail)  \
# id
# 12195   Paktya; Kandahar; Helmand; Kabul; Nimroz; Badgis
# 17395                                                n.a
# 22431  Balkh; Badkhshan; Daikondi, Badghis; Ghor; Bam...
#
# ...

# %% [raw]
# damage y LCU *  xr 2000 = damage current USD current MER
# damage y LCU * xr 2015 = damage current USD constant 2015 MER
#
# --> conv= xr 2015 / xr y

# %%
# get country list
countries=list(set(damage_natcat['iso3']))
len(countries)
# Out:
# 158

# %%
damage_natcat.loc[(damage_natcat['iso3']=='TWN')]
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 5268   1991  01/01/1991 00:00      1991          1  30/06/1991 00:00    1991
# 6053   1992  01/06/1992 00:00      1992          6  30/09/1992 00:00    1992
# 6756   1993  01/06/1993 00:00      1993          6  30/09/1993 00:00    1993
# 7216   1994  01/01/1994 00:00      1994          1  31/01/1994 00:00    1994
# 8462   1995  01/10/1995 00:00      1995         10  31/10/1995 00:00    1995
# 13877  2002  01/04/2002 00:00      2002          4  31/05/2002 00:00    2002
# 27842  2015  01/04/2015 00:00      2015          4  05/11/2015 00:00    2015
#
#        end_mon    event type     subtype  ...    Affected Area  \
# id                                        ...
# 5268         6  Drought    D  dr:Drought  ...            S, C,
# 6053         9  Drought    D  dr:Drought  ...  Entire country,
# 6756         9  Drought    D  dr:Drought  ...            N, C,
# ...

# %%
# list for countries without own currency
cwooc={'TKL': 'NZL',
       'PRI': 'USA',
       'TUV': 'AUS',
       'MHL': 'USA',
       'ASM': 'USA'
      }

# %%
cwooc.keys()
# Out:
# dict_keys(['TKL', 'PRI', 'TUV', 'MHL', 'ASM'])

# %%
years=np.arange(1980,2017)
for c in countries:
    print(c)
    # use NZL for TKL as they have the same currency
    if c =='TKL':
        c='NZL'
    # TWN is not listed in WDI therefore we use pwt
    try:
        xr_c_2015=pwt.loc[(pwt['countrycode']==c) & (pwt['year']==2015), 'xr'].values[0]
        xr_c_2017=pwt.loc[(pwt['countrycode']==c) & (pwt['year']==2017), 'xr'].values[0]
        source='pwt'
    except IndexError:
        
        xr_c_2015=xr.loc[xr['Country Code']==c, '2015'].values[0]
        xr_c_2017=xr.loc[xr['Country Code']==c, '2017'].values[0]
        source='wdi'
        #check the differences
    for y in years:
        try:
            xr_c_y=pwt.loc[(pwt['countrycode']==c) & (pwt['year']==y), 'xr'].values[0]
            source='pwt'
        except IndexError:
            xr_c_y=xr.loc[xr['Country Code']==c, str(y)].values[0]
            source='wdi'
        
        cf_2015=xr_c_2015/xr_c_y
        cf_2017=xr_c_2017/xr_c_y
        damage_natcat.loc[(damage_natcat['iso3']==c) & (damage_natcat['year']==y), 'cf_current_constant2015_xr']=cf_2015
        damage_natcat.loc[(damage_natcat['iso3']==c) & (damage_natcat['year']==y), 'cf_current_constant2017_xr']=cf_2017
        damage_natcat.loc[(damage_natcat['iso3']==c) & (damage_natcat['year']==y), 'cf_xr']=source
# Out:
# FSM
# GIN
# MOZ
# BGD
# PER
# SGP
# FJI
# HND
# HRV
# RUS
# ISR
# KEN
# GTM
# AZE
# CYP
# SLV
# DJI
# PNG
# MLI
# KAZ
# CIV
# BFA
# POL
# CAF
# IND
# BIH
# TKL
# ETH
# BGR
# AGO
# MAR
# TGO
# SYR
# PRK
# VEN
# MDG
# TJK
# LSO
# UKR
# WSM
# GMB
# CRI
# STP
# AFG
# PAN
# DMA
# CZE
# PHL
# MYS
# SSD
# RWA
# MMR
# NER
# TZA
# UGA
# ECU
# ZAF
# PRT
# DZA
# NAM
# JOR
# GEO
# FRA
# ATG
# COM
# SYC
# BRB
# SWZ
# IDN
# MNG
# KHM
# KOR
# SVN
# THA
# SLB
# TLS
# ERI
# VNM
# LKA
# ZWE
# ZMB
# COL
# URY
# BEN
# SDN
# SVK
# BWA
# PRI
# CUB
# NGA
# LCA
# ALB
# VGB
# BOL
# CHE
# KIR
# USA
# CHN
# SEN
# CPV
# MWI
# ARM
# TTO
# ITA
# TUN
# BEL
# MEX
# PAK
# IRN
# TCD
# MUS
# LTU
# NPL
# TUV
# IRQ
# SRB
# DEU
# BDI
# HTI
# SOM
# TUR
# DOM
# BRA
# LBR
# ASM
# ROU
# MDA
# GRD
# ARG
# PRY
# JAM
# MHL
# JPN
# DNK
# CAN
# CHL
# GNB
# AUS
# COD
# CMR
# VUT
# GBR
# LAO
# MRT
# ESP
# AUT
# UZB
# COG
# TWN
# GUY
# LBN
# NZL
# NIC
# HUN
# MKD
# GHA
# GRC
# MNE
# KGZ

# %%
# Out:
# id
# 0        EUR
# 9        SSA
# 10       SSA
# 11       SSA
# 12       SSA
#         ...
# 29778    EUR
# 29936    CHN
# 30097    CHN
# 30236    SWA
# 30375    SSA
# Name: Reg_name, Length: 919, dtype: object

# %%
list(set(damage_natcat.loc[damage_natcat['cf_current_constant2015_xr'].isna(), 'iso3']))
# cuba, somalia, south sudan before 2011, croatia before 1990
# Out:
# ['PRI', 'TUV', 'CUB', 'TKL', 'MHL', 'SOM', 'PRK', 'SSD', 'HRV', 'ASM']

# %%
#
damage_natcat.loc[damage_natcat['iso3']=='SOM','tot_damage_currentUSD_currentXR']
# Out:
# id
# 9          6.0
# 1453       6.0
# 3025      10.0
# 3462      21.6
# 9418       9.6
# 11960     48.0
# 16238    120.0
# 19246      0.0
# 20152      0.0
# 21670      0.0
# 22444    156.0
# 23548      5.0
# 28113      1.0
# 29015     17.5
# Name: tot_damage_currentUSD_currentXR, dtype: float64

# %% [markdown]
# ### 1.2 conversion to constant 2015 USD ('tot_dam_constant2015USD_constant2015XR')

# %% [markdown]
# Deflator:
# We use the wdi dataset Consumer price index (2010 = 100)
#
# https://data.worldbank.org/indicator/FP.CPI.TOTL.ZG

# %%
cpi=pd.read_csv('/home/insauer/projects/droughts_annika/inga_data/socio_economic/API_FP.CPI.TOTL_DS2_en_csv_v2_371391/API_FP.CPI.TOTL_DS2_en_csv_v2_371391.csv',
                header=2)
cpi
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                         Indicator Name Indicator Code     1960      1961  \
# 0    Consumer price index (2010 = 100)    FP.CPI.TOTL      NaN       NaN
# 1    Consumer price index (2010 = 100)    FP.CPI.TOTL      NaN       NaN
# 2    Consumer price index (2010 = 100)    FP.CPI.TOTL      NaN       NaN
# 3    Consumer price index (2010 = 100)    FP.CPI.TOTL      NaN       NaN
# ...

# %%
dose = pd.read_csv(f"{path_cluster}/dose/DoseRegions.csv")
dose
# Out:
#      GID_0     GID_1       NAME_0              NAME_1 ENGTYPE_1  \
# 0      AFG  AFG.10_1  Afghanistan                Ghor  Province
# 1      AFG  AFG.11_1  Afghanistan             Hilmand  Province
# 2      AFG  AFG.12_1  Afghanistan               Hirat  Province
# 3      AFG  AFG.13_1  Afghanistan             Jawzjan  Province
# 4      AFG  AFG.14_1  Afghanistan               Kabul  Province
# ...    ...       ...          ...                 ...       ...
# 3426   ZWE   ZWE.5_1     Zimbabwe    Mashonaland East  Province
# 3427   ZWE   ZWE.6_1     Zimbabwe    Mashonaland West  Province
# 3428   ZWE   ZWE.7_1     Zimbabwe            Masvingo  Province
# 3429   ZWE   ZWE.8_1     Zimbabwe  Matabeleland North  Province
# 3430   ZWE   ZWE.9_1     Zimbabwe  Matabeleland South  Province
#
#      two_letter_code
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 3426             NaN
# ...

# %%
conv_factor_2015_2010=cpi.loc[cpi['Country Code']=='USA', '2015'].values[0]
conv_factor_2015_2010
# Out:
# 108.695721960694

# %%
# convert to 2010 CPI countries included in WDI
country_list=list(set(damage_natcat['iso3'].dropna()))
years= np.arange(1980,2023)
missing_countries=[]
for c in country_list:
        try:
            conv_factor_2016_2010=100./cpi.loc[cpi['Country Code']==c, '2016'].values[0]
            conv_factor_2010_2015=cpi.loc[cpi['Country Code']==c, '2015'].values[0]/100
            if np.isnan(conv_factor_2016_2010) | np.isnan(2010_2015) :
                conv_factor_2016_2010=1
                conv_factor_2010_2015=1
                missing_countries.append(c)
        except IndexError:
            
            if c=='TKL':
                conv_factor_2016_2010=100./cpi.loc[cpi['Country Code']=='NZL', '2016'].values[0]
                conv_factor_2010_2015=cpi.loc[cpi['Country Code']=='NZL', '2015'].values[0]/100
            elif c=='TWN':
                conv_factor_2016_2010=100./cpi.loc[cpi['Country Code']=='CHN', '2016'].values[0]
                conv_factor_2010_2015=cpi.loc[cpi['Country Code']=='CHN', '2015'].values[0]/100
            else:
                missing_countries.append(c)
 

        damage_natcat.loc[(damage_natcat['iso3']==c), 'cpi_2016_to_2010']=conv_factor_2016_2010
        damage_natcat.loc[(damage_natcat['iso3']==c), 'cpi_2010_to_2015']=conv_factor_2010_2015

# %%
print(missing_countries)
# Out:
# ['BIH', 'SYR', 'PRK', 'COM', 'ERI', 'PRI', 'CUB', 'VGB', 'TUV', 'SOM', 'ASM', 'ARG', 'MHL']

# %%
damage_natcat['cpi_2015_to_2016_wdi']=damage_natcat['cpi_2016_to_2010']*damage_natcat['cpi_2010_to_2015']
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
damage_org = pd.read_excel("/home/insauer/projects/droughts_annika/inga_data/1980-2016_Masterdatei_NatCat_worldwide_no-pw_2005conversions_PPP.xlsx")
damage_org
# Out:
#        Unnamed: 0  Event ID     MR Number             MR ID  \
# 0               0     15344  MR198001D066  MR198001D066_ESP
# 1               1     14808  MR198001A033  MR198001A033_PRT
# 2               2     10844  MR198001B003  MR198001B003_AUS
# 3               3     12372  MR198001B005  MR198001B005_AFG
# 4               4     13659  MR198001B022  MR198001B022_GRC
# ...           ...       ...           ...               ...
# 30557       30557  14806040  MR201612C444  MR201612C444_ECU
# 30558       30558  14794827  MR201612B442      MR201612B442
# 30559       30559  14735291  MR201612B442  MR201612B442_CAN
# 30560       30560  14733806  MR201612C425  MR201612C425_BOL
# 30561       30561  14733982  MR201612D426  MR201612D426_USA
#
#                           Period  Year      Begin        End  \
# 0      January 1980- August 1982  1980 1980-01-01 1982-08-31
# 1                       1.1.1980  1980 1980-01-01 1980-01-01
# ...

# %%
damage_org.columns
# Out:
# Index(['Unnamed: 0', 'Event ID', 'MR Number', 'MR ID', 'Period', 'Year',
#        'Begin', 'End', 'Event Text',
#        'Event Family \n(A = Geophysical events; \nB = Meteorological events; \nC = Hydrological events; \nD = Climatological/Extreme temperature events)',
#        'Subevent',
#        'Association Type \n(Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me') ',
#        'Continent', 'Country Name', 'Country ISO3',
#        'Income Group (year of loss)\n(1 = High Income; \n2 = Upper-Middle Income; \n3 = Lower-Middle Income; \n4 = Low Income)',
#        'Income Group (today)\n(1 = High Income; \n2 = Upper-Middle Income; \n3 = Lower-Middle Income; \n4 = Low Income)',
#        'Affected Area', 'Affected Area (Detail)', 'Description',
#        'official overall losses for publication\n(US$ m, original values)',
#        'official insured losses for publication\n(US$ m, original values)',
# ...

# %%
countries_2015=list(set(damage_org.loc[(damage_org['Country ISO3'].isin(missing_countries)) & ((damage_org['Year']==2015)), 'Country ISO3' ]))

# %%
list(set(damage_org.loc[(damage_org['Country ISO3'].isin(missing_countries)) & ((damage_org['Year']==2016)), 'Country ISO3' ]))
# Out:
# ['MHL', 'SOM', 'PRK', 'ARG', 'PRI', 'CUB']

# %%
countries_2015
# Out:
# ['SYR', 'BIH', 'TUV', 'MHL', 'SOM', 'VGB', 'PRK', 'ARG', 'PRI', 'CUB']

# %%
damage_natcat.loc[damage_natcat['Year']'tot_loss']
# Out:
# Index(['year', 'begin', 'begin_yr', 'begin_mon', 'end', 'end_yr', 'end_mon',
#        'event', 'type', 'subtype', 'iso3', 'country', 'country_read',
#        'Continent', 'tot_loss', 'ins_loss', 'tot_loss_GDP', 'tot_loss_GCP',
#        'tot_loss_CPI', 'Fatalities', 'Longitude', 'Latitude', 'Reg_name', 'ID',
#        'Reg_ID', 'CPI_conv', 'GDP_conv', 'unexact_conv', 'comment',
#        'MR Number', 'MR ID',
#        'Association Type \n(Single + Main = Single-Country-Event; Country = Country data from Multi-Country-Event; Region =Multi-Country-Event; see sheet 'Read me') ',
#        'Country Name', 'Affected Area', 'Affected Area (Detail)',
#        'Description', 'Catastrophe Class', 'Geocoded Place',
#        'cpi_2016_to_2010', 'cpi_2010_to_2015', 'cpi_2015_to_2016_wdi'],
#       dtype='object')

# %%
nominal_dam='estimated overall losses for statistics\n(US$ m, original values)'
cpi_dam='estimated overall losses for statistics\n(US$ m, adjusted to inflation to 2016 values based on national CPI)'

for c in country_list:
    tot_loss_CPI=damage_org.loc[(damage_org['Country ISO3']==c) & (damage_org['Year']==2015), cpi_dam]
    tot_loss=damage_org.loc[(damage_org['Country ISO3']==c) & (damage_org['Year']==2015), nominal_dam]

    factor=(tot_loss_CPI/tot_loss).mean()
    print(factor)
    damage_natcat.loc[damage_natcat['iso3']==c,'conv_factor_2015_natcat']=1/factor
# Out:
# 1.0304552323284
# 0.6513276129328
# nan
# 1.0010647918971
# 0.9975800136856
# 1.0403223412355
# 0.9936325866456
# 0.9967172292357
# nan
# nan
# 1.0077968113128
# 1.0112170615651999
# 0.9081813997396
# 0.9808029119146999
# 0.9959942534945
# 1.02263337233
# 1.0062629855497003
# nan
# 1.0120182922079997
# 0.8959070190019001
# 1.0049041055353998
# 1.0047765751625
# 1.0126151288699996
# 1.0279294380382
# 1.00389216919
# 1.0126151288699998
# 1.0106846834078
# 0.9289652349996
# 0.8603818333071
# 0.9507557185716999
# 1.0126151289227
# 1.03683984431
# 1.0036673846896
# 1.01261512887
# 0.9618540086851
# 1.0063975129862
# 1.0111670001197
# 1.0048842192516
# 0.9837807163766
# 0.9812990250122001
# 1.0170097640873
# 1.0169892350273
# 0.9653990927482999
# 0.994788576982
# 0.8241154570265999
# 1.0188248757403
# 1.0241124489006999
# 1.08020494667
# 0.8528959499540999
# nan
# 1.001716575558
# 1.0240455380495
# 1.0174305875049
# 1.0313671011263001
# 0.6930208319172
# 0.999229912
# 1.0133129370646
# ...

# %%
damage_natcat['damage_cpi2015_wdi']=damage_natcat['tot_loss_CPI']*damage_natcat['cpi_2015_to_2016_wdi']
damage_natcat['damage_cpi2015_natcat']=damage_natcat['tot_loss_CPI']*damage_natcat['conv_factor_2015_natcat']

# %%
damage_natcat['damage_cpi2016']=damage_natcat['tot_loss_CPI']
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
damage_natcat['damage_cpi2015_final']=damage_natcat['damage_cpi2015_natcat']
damage_natcat.loc[damage_natcat['damage_cpi2015_final'].isna(), 'damage_cpi2015_final']=damage_natcat['damage_cpi2015_wdi']

# %%
damage_natcat
# Out:
#        year             begin  begin_yr  begin_mon               end  end_yr  \
# id
# 0      1980  01/01/1980 00:00      1980          1  31/08/1982 00:00    1982
# 9      1980  01/01/1980 00:00      1980          1  31/01/1980 00:00    1980
# 10     1980  01/01/1980 00:00      1980          1  31/12/1980 00:00    1980
# 11     1980  01/01/1980 00:00      1980          1  31/12/1985 00:00    1985
# 12     1980  01/01/1980 00:00      1980          1  31/12/1982 00:00    1982
# ...     ...               ...       ...        ...               ...     ...
# 29778  2016  01/07/2016 00:00      2016          7  17/08/2016 00:00    2016
# 29936  2016  01/08/2016 00:00      2016          8  05/09/2016 00:00    2016
# 30097  2016  01/09/2016 00:00      2016          9  24/09/2016 00:00    2016
# 30236  2016  01/10/2016 00:00      2016         10  31/12/2016 00:00    2016
# 30375  2016  01/11/2016 00:00      2016         11  31/12/2016 00:00    2016
#
# ...

# %%
emdat.columns
# Out:
# Index(['DisNo.', 'Historic', 'Classification Key', 'Disaster Group',
#        'Disaster Subgroup', 'Disaster Type', 'Disaster Subtype',
#        'External IDs', 'Event Name', 'ISO', 'Country', 'Subregion', 'Region',
#        'Location', 'Origin', 'Associated Types', 'OFDA/BHA Response', 'Appeal',
#        'Declaration', 'AID Contribution ('000 US$)', 'Magnitude',
#        'Magnitude Scale', 'Latitude', 'Longitude', 'River Basin', 'Start Year',
#        'Start Month', 'Start Day', 'End Year', 'End Month', 'End Day',
#        'Total Deaths', 'No. Injured', 'No. Affected', 'No. Homeless',
#        'Total Affected', 'Reconstruction Costs ('000 US$)',
#        'Reconstruction Costs, Adjusted ('000 US$)',
#        'Insured Damage ('000 US$)', 'Insured Damage, Adjusted ('000 US$)',
#        'Total Damage ('000 US$)', 'Total Damage, Adjusted ('000 US$)', 'CPI',
#        'Admin Units', 'Entry Date', 'Last Update'],
#       dtype='object')

# %%
conv_factor=emdat.loc[emdat['Start Year']==2015,'CPI']/100
emdat["damage_cpi2015_final"]=emdat["Total Damage, Adjusted ('000 US$)"]*conv_factor
emdat
# Out:
#               DisNo. Historic Classification Key Disaster Group  \
# 1213   1980-9005-DJI      Yes    nat-cli-dro-dro        Natural
# 1214   1980-9005-SDN      Yes    nat-cli-dro-dro        Natural
# 1215   1980-9005-SOM      Yes    nat-cli-dro-dro        Natural
# 1216   1980-9011-LKA      Yes    nat-cli-dro-dro        Natural
# 1217   1980-9114-BEN      Yes    nat-cli-dro-dro        Natural
# ...              ...      ...                ...            ...
# 12919  2023-9589-URY       No    nat-cli-dro-dro        Natural
# 12920  2023-9651-BRA       No    nat-cli-dro-dro        Natural
# 12921  2023-9706-BOL       No    nat-cli-dro-dro        Natural
# 12922  2023-9868-USA       No    nat-cli-dro-dro        Natural
# 12923  2023-9872-CHN       No    nat-cli-dro-dro        Natural
#
#       Disaster Subgroup Disaster Type Disaster Subtype          External IDs  \
# 1213     Climatological       Drought          Drought                   NaN
# ...

# %% [markdown]
# # PPP conversion to 2017

# %%
pwt= pd.read_excel('/home/insauer/projects/droughts_annika/inga_data/socio_economic/pwt1001.xlsx')

# %%
tot_gdp = pd.read_csv(f"{path_cluster}/dose/"
    "DOSE_V2_grp_usd_2015_running_11yr_mean.csv", index_col=0)

# %%
tot_gdp
# Out:
#          GID_0     GID_1       NAME_0              NAME_1 ENGTYPE_1  1953  \
# AFG        AFG       AFG  Afghanistan         Afghanistan   Country   NaN
# AFG.10_1   AFG  AFG.10_1  Afghanistan                Ghor  Province   NaN
# AFG.11_1   AFG  AFG.11_1  Afghanistan             Hilmand  Province   NaN
# AFG.12_1   AFG  AFG.12_1  Afghanistan               Hirat  Province   NaN
# AFG.13_1   AFG  AFG.13_1  Afghanistan             Jawzjan  Province   NaN
# ...        ...       ...          ...                 ...       ...   ...
# ZWE.5_1    ZWE   ZWE.5_1     Zimbabwe    Mashonaland East  Province   NaN
# ZWE.6_1    ZWE   ZWE.6_1     Zimbabwe    Mashonaland West  Province   NaN
# ZWE.7_1    ZWE   ZWE.7_1     Zimbabwe            Masvingo  Province   NaN
# ZWE.8_1    ZWE   ZWE.8_1     Zimbabwe  Matabeleland North  Province   NaN
# ZWE.9_1    ZWE   ZWE.9_1     Zimbabwe  Matabeleland South  Province   NaN
#
#           1954  1955  1956  1957  ...  2011  2012  2013  2014  2015  2016  \
# ...

# %%
emdat=pd.read_excel('/home/insauer/projects/droughts_annika/inga_data/public_emdat_custom_request_2024-06-13_7d875f23-49ff-443a-be16-285600dd2f7b.xlsx')
emdat=emdat[(emdat['Disaster Type']=='Drought')& (emdat['Start Year']>=1980)& (emdat['End Year']<2024)]
